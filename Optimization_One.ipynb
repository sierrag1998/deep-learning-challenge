# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns=["EIN","NAME"])

# %%
# Generate our categorical variable lists
cat = df.dtypes[df.dtypes == "object"].index.tolist()
cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
# Convert categorical data to numeric with `pd.get_dummies`
new_df = pd.get_dummies(data=df, columns=['APPLICATION_TYPE','INCOME_AMT', 'AFFILIATION','CLASSIFICATION','USE_CASE','ORGANIZATION','SPECIAL_CONSIDERATIONS'])
new_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                       0               0                      0
# 1                       0               0                      1
# 2                       0               0                      0
# 3                       0               0                      1
# 4                       1               0                      0
# ...                   ...             ...                    ...
# 34294                   0               0                      0
# 34295                   0               0                      0
# 34296                   0               0                      1
# 34297                   0               0                      0
# 34298                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                        1                         1
# 1                        0                         0
# 2                        1                         1
# 3                        0                         0
# 4                        0                         0
# ...                    ...                       ...
# 34294                    1                         1
# 34295                    1                         1
# 34296                    0                         1
# 34297                    1                         1
# 34298                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                       0                         1                         0
# 1                       0                         1                         0
# 2                       0                         1                         0
# 3                       1                         1                         0
# 4                       1                         1                         0
# ...                   ...                       ...                       ...
# 34294                   0                         1                         0
# 34295                   0                         1                         0
# 34296                   0                         1                         0
# 34297                   0                         1                         0
# 34298                   0                         1                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
# Remove IS_SUCCESSFUL target from features data
y = new_df.IS_SUCCESSFUL.values
X = new_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 8)                 936
#
#  dense_22 (Dense)            (None, 10)                90
#
#  dense_23 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,037
# Trainable params: 1,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 4ms/step - loss: 0.6051 - accuracy: 0.6952
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5593 - accuracy: 0.7288
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5526 - accuracy: 0.7308
# Epoch 4/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5502 - accuracy: 0.7324
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5483 - accuracy: 0.7331
# Epoch 6/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5470 - accuracy: 0.7326
# Epoch 7/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5460 - accuracy: 0.7326
# Epoch 8/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5453 - accuracy: 0.7342
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7335
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5444 - accuracy: 0.7339
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5440 - accuracy: 0.7342
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7345
# Epoch 13/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5431 - accuracy: 0.7339
# Epoch 14/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5430 - accuracy: 0.7350
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7350
# Epoch 16/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5422 - accuracy: 0.7346
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7359
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7347
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5416 - accuracy: 0.7354
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5420 - accuracy: 0.7353
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7356
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7362
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7362
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5410 - accuracy: 0.7365
# Epoch 25/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5411 - accuracy: 0.7365
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5406 - accuracy: 0.7356
# Epoch 27/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5407 - accuracy: 0.7369
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5408 - accuracy: 0.7365
# Epoch 29/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5406 - accuracy: 0.7364
# Epoch 30/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5406 - accuracy: 0.7363
# Epoch 31/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5404 - accuracy: 0.7370
# Epoch 32/100
# 804/804 [==============================] - 9s 11ms/step - loss: 0.5404 - accuracy: 0.7367
# Epoch 33/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.5400 - accuracy: 0.7366
# Epoch 34/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5400 - accuracy: 0.7372
# Epoch 35/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5399 - accuracy: 0.7374
# Epoch 36/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5397 - accuracy: 0.7374
# Epoch 37/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5396 - accuracy: 0.7367
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5394 - accuracy: 0.7376
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5393 - accuracy: 0.7370
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5394 - accuracy: 0.7375
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5392 - accuracy: 0.7380
# Epoch 42/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5392 - accuracy: 0.7376
# Epoch 43/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5394 - accuracy: 0.7373
# Epoch 44/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5390 - accuracy: 0.7376
# Epoch 45/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5388 - accuracy: 0.7385
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5391 - accuracy: 0.7375
# Epoch 47/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5390 - accuracy: 0.7384
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5387 - accuracy: 0.7380
# Epoch 49/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5384 - accuracy: 0.7379
# Epoch 50/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5389 - accuracy: 0.7383
# Epoch 51/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5389 - accuracy: 0.7381
# Epoch 52/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5385 - accuracy: 0.7375
# Epoch 53/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5383 - accuracy: 0.7388
# Epoch 54/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5386 - accuracy: 0.7384
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5385 - accuracy: 0.7379
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5384 - accuracy: 0.7389
# Epoch 57/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5385 - accuracy: 0.7385
# Epoch 58/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5383 - accuracy: 0.7386
# Epoch 59/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5385 - accuracy: 0.7382
# Epoch 60/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5381 - accuracy: 0.7382
# Epoch 61/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5383 - accuracy: 0.7379
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5381 - accuracy: 0.7379
# Epoch 63/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5380 - accuracy: 0.7380
# Epoch 64/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5382 - accuracy: 0.7387
# Epoch 65/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5380 - accuracy: 0.7381
# Epoch 66/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5379 - accuracy: 0.7390
# Epoch 67/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5380 - accuracy: 0.7383
# Epoch 68/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5379 - accuracy: 0.7380
# Epoch 69/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5381 - accuracy: 0.7379
# Epoch 70/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5380 - accuracy: 0.7377
# Epoch 71/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5378 - accuracy: 0.7381
# Epoch 72/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5377 - accuracy: 0.7374
# Epoch 73/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5379 - accuracy: 0.7383
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5378 - accuracy: 0.7382
# Epoch 75/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5379 - accuracy: 0.7383
# Epoch 76/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5374 - accuracy: 0.7381
# Epoch 77/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 78/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5377 - accuracy: 0.7388
# Epoch 79/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5376 - accuracy: 0.7381
# Epoch 80/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5376 - accuracy: 0.7385
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5374 - accuracy: 0.7379
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5374 - accuracy: 0.7377
# Epoch 83/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5378 - accuracy: 0.7376
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5376 - accuracy: 0.7385
# Epoch 85/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.7379
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 87/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.7379
# Epoch 88/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5375 - accuracy: 0.7387
# Epoch 89/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5374 - accuracy: 0.7388
# Epoch 90/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5370 - accuracy: 0.7392
# Epoch 91/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5371 - accuracy: 0.7386
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.7386
# Epoch 93/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7392
# Epoch 94/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5373 - accuracy: 0.7387
# Epoch 95/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5368 - accuracy: 0.7395
# Epoch 96/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5368 - accuracy: 0.7393
# Epoch 97/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5371 - accuracy: 0.7390
# Epoch 98/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5370 - accuracy: 0.7394
# Epoch 99/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5371 - accuracy: 0.7387
# Epoch 100/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5369 - accuracy: 0.7388

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 3s - loss: 0.5567 - accuracy: 0.7233 - 3s/epoch - 11ms/step
# Loss: 0.5566833019256592, Accuracy: 0.7232652902603149

# %%
# Export our model to HDF5 file
from tensorflow.keras.models import load_model
model=nn
model.save('opt_model1.HDF5')
# Out:
# INFO:tensorflow:Assets written to: opt_model1.HDF5/assets
