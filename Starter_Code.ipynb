# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns=["EIN","NAME"])
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
#Replace in dataframe
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T2", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T13", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T12", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T25", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T14", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T29", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T15", "Other", df.APPLICATION_TYPE)
df["APPLICATION_TYPE"] = np.where(df.APPLICATION_TYPE == "T17", "Other", df.APPLICATION_TYPE)

# %%
# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C5200        1
# C2170        1
# C1248        1
# C1283        1
# C6100        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
#Replace in dataframe
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1250", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C8200", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1278", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1238", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1237", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1235 ", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C7210", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1720", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2400", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C4100 ", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C0", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1260", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2710", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1234", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1246", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1267", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C3200", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1256", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C6100 ", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2500", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1900", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C3700", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2190", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1728", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C4500", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C4120", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1732", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2600", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1236", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C5200", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1235", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C4100", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C5200", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1600", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1257", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C8210", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1580", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C4200", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1370", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2150", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2561", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1820", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1245", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1570", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1283", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C1248", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2170", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2570", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C2380", "Other", df.CLASSIFICATION)
df["CLASSIFICATION"] = np.where(df.CLASSIFICATION == "C6100", "Other", df.CLASSIFICATION)

# %%
# Look at CLASSIFICATION value counts for binning
df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# Other      143
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# Name: CLASSIFICATION, dtype: int64

# %%
# Generate our categorical variable lists
cat = df.dtypes[df.dtypes == "object"].index.tolist()
cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
# Convert categorical data to numeric with `pd.get_dummies`
new_df = pd.get_dummies(data=df, columns=['APPLICATION_TYPE','INCOME_AMT', 'AFFILIATION','CLASSIFICATION','USE_CASE','ORGANIZATION','SPECIAL_CONSIDERATIONS'])
new_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
# Remove IS_SUCCESSFUL target from features data
y = new_df.IS_SUCCESSFUL.values
X = new_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 8)                 520
#
#  dense_10 (Dense)            (None, 5)                 45
#
#  dense_11 (Dense)            (None, 1)                 6
#
# ...
# Total params: 571
# Trainable params: 571
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 2s - loss: 0.5563 - accuracy: 0.7247 - 2s/epoch - 8ms/step
# Loss: 0.5562919974327087, Accuracy: 0.7246647477149963

# %%
mc = keras.callbacks.ModelCheckpoint('starter_model.HDF5',save_freq=5)
nn.fit(X_train_scaled,y_train,epochs=100, callbacks=[mc])
# Out:
# Epoch 1/100
# ...
# 804/804 [==============================] - 196s 243ms/step - loss: 0.5936 - accuracy: 0.7140
# Epoch 2/100
# INFO:tensorflow:Assets written to: starter_model.HDF5/assets
# ...
# 804/804 [==============================] - 558s 691ms/step - loss: 0.5623 - accuracy: 0.7269
# Epoch 3/100
# ...
#  17/804 [..............................] - ETA: 10:57 - loss: 0.5427 - accuracy: 0.7353INFO:tensorflow:Assets written to: starter_model.HDF5/assets
# ...
#     116         objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
#     117         functions = save_impl.wrap_layer_functions(
# --> 118             self.obj, serialization_cache
#     119         )
#     120         # Attribute validator requires that the default save signature is added
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/keras/saving/saved_model/save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     223             for fn in fns.values():
# ...

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 14s 12ms/step - loss: 0.5542 - accuracy: 0.7310
# Epoch 2/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.5527 - accuracy: 0.7295
# Epoch 3/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5511 - accuracy: 0.7307
# Epoch 4/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5505 - accuracy: 0.7319
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5499 - accuracy: 0.7317
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5493 - accuracy: 0.7327
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7328
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5485 - accuracy: 0.7331
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 10/100
# ...

# %%
# Export our model to HDF5 file

model=nn
model.save('starter_model.HDF5')
# Out:
# INFO:tensorflow:Assets written to: starter_model.HDF5/assets
